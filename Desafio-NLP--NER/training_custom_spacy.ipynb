# %% [markdown]
# <a href="https://colab.research.google.com/github/rrfsantos/Desafios-NLP/blob/main/Desafio-NLP--NER/training_custom_spacy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --user -U pip setuptools wheel
# !pip install --user -U spacy[transformers,lookups]
# !python -m spacy download en_core_web_lg
#!python -m spacy download en_core_web_trf
# !pip install spacy-transformers

# %%
# !python -m spacy info
# Out:
# 2021-04-25 17:00:55.647978: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
#
# ============================== Info about spaCy ==============================
#
# spaCy version    3.0.6
# Location         /usr/local/lib/python3.7/dist-packages/spacy
# Platform         Linux-4.19.112+-x86_64-with-Ubuntu-18.04-bionic
# Python version   3.7.10
# Pipelines

# %%
import spacy
import warnings
import pandas as pd

warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
workdir_path = '/content/drive/My Drive/desafio 2/'
os.chdir(workdir_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### A maneira recomendada para treinar pipelines spaCy é por meio do comando spacy train na linha de comando. É preciso um único arquivo de configuração config.cfg que inclui todas as configurações e hiperparâmetros. Download do arquivo em https://spacy.io/usage/training#quickstart. Após slavar a configuração inicial no arquivo base_config.cfg, utilizar o comando init fill-config para preencher os padrões restantes.

# %%
# !python -m spacy init fill-config base_config.cfg config.cfg
# Out:
# 2021-04-25 17:03:55.441731: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# ✔ Auto-filled config with all values
# ✔ Saved config
# config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %% [markdown]
# ### Corpus

# %%
df = pd.read_csv('corona_dataset.csv')

# %%
df = df.dropna(subset=['body']).astype(str)

# %%
text_join = " ".join([text for text in df.body])

# %% [markdown]
# ## Treinamento e Avaliação dos modelos

# %% [markdown]
# #### ---> s800 <---

# %%
# !python -m spacy train config.cfg --output ./SPACYdata/Model/s800/ --paths.train ./SPACYdata/train/iob_train_s800.spacy --paths.dev ./SPACYdata/test/iob_test_s800.spacy --gpu-id 0
# Out:
# 2021-04-25 17:04:00.752374: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# [2021-04-25 17:04:03,505] [INFO] Set up nlp object from config
# [2021-04-25 17:04:03,517] [INFO] Pipeline: ['transformer', 'ner']
# [2021-04-25 17:04:03,521] [INFO] Created vocabulary
# [2021-04-25 17:04:03,522] [INFO] Finished initializing nlp object
# Downloading: 100% 481/481 [00:00<00:00, 566kB/s]
# Downloading: 100% 899k/899k [00:00<00:00, 2.40MB/s]
# Downloading: 100% 456k/456k [00:00<00:00, 1.47MB/s]
# Downloading: 100% 1.36M/1.36M [00:00<00:00, 3.49MB/s]
# Downloading: 100% 501M/501M [00:06<00:00, 75.8MB/s]
# [2021-04-25 17:04:30,408] [INFO] Initialized pipeline components: ['transformer', 'ner']
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ...

# %%
nlp = spacy.load('SPACYdata/Model/s800/model-best')
doc = nlp(text_join)
for ent in doc.ents:
  # Print the entity text and its label
  print(ent.text, ent.label_)
# Out:
# COVID-19 virus SPECIES
# COVID-19, a disease caused by the new coronavirus SPECIES
# Los Angeles Lakers SPECIES
# “every dollar donated is a dollar towards saving lives. SPECIES
# ” The SPECIES
# “every dollar donated is a dollar towards saving lives. SPECIES
# ” American SPECIES
# Ottawa Senators SPECIES
# COVID-19 SPECIES
# IndyCar SPECIES
# NASCAR SPECIES
# IndyCar SPECIES
# NASCAR SPECIES
# “nowhere near” proper readiness for outbreaks like the new coronavirus SPECIES
# Walgreens Boots Alliance Inc  said SPECIES
# Yeshiva University SPECIES
# British American Tobacco SPECIES
# tobacco SPECIES
# HIV SPECIES
# Fiat Chrysler Automobiles NV SPECIES
# FCA SPECIES
# Chinese virus SPECIES
# — or SPECIES
# — puts SPECIES
# human SPECIES
# Nissan Motor Co SPECIES
# COVID-19 coronavirus SPECIES
# Trump SPECIES
# Trump SPECIES
# “many steps” he SPECIES
# COVID-19. SPECIES
# Covid-19. SPECIES
# “campaign SPECIES
# ...

# %% [markdown]
# #### ---> linnaeus <---

# %%
# !python -m spacy train config.cfg --output ./SPACYdata/Model/linnaeus/ --paths.train ./SPACYdata/train/iob_train_linnaeus.spacy --paths.dev ./SPACYdata/test/iob_test_linnaeus.spacy --gpu-id 0
# Out:
# 2021-04-25 18:01:04.818725: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# [2021-04-25 18:01:07,097] [INFO] Set up nlp object from config
# [2021-04-25 18:01:07,106] [INFO] Pipeline: ['transformer', 'ner']
# [2021-04-25 18:01:07,111] [INFO] Created vocabulary
# [2021-04-25 18:01:07,111] [INFO] Finished initializing nlp object
# [2021-04-25 18:01:17,634] [INFO] Initialized pipeline components: ['transformer', 'ner']
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['transformer', 'ner']
# ℹ Initial learn rate: 0.0
# E    #       LOSS TRANS...  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  -------------  --------  ------  ------  ------  ------
#   0       0       13389.26    788.61    0.27    0.16    0.79    0.00
# ...

# %%
nlp = spacy.load('SPACYdata/Model/linnaeus/model-best')
doc = nlp(text_join)
for ent in doc.ents:
  # Print the entity text and its label
  print(ent.text, ent.label_)
# Out:
# patient SPECIES
# people SPECIES
# people SPECIES
# “every SPECIES
# ” The SPECIES
# “every SPECIES
# ” American SPECIES
# Patients SPECIES
# people SPECIES
# people SPECIES
# “nowhere SPECIES
# ” proper SPECIES
# children SPECIES
# man SPECIES
# men SPECIES
# HIV SPECIES
# men SPECIES
# women SPECIES
# people SPECIES
# — or SPECIES
# — puts SPECIES
# people SPECIES
# human SPECIES
# people SPECIES
# woman SPECIES
# patients SPECIES
# people SPECIES
# patients SPECIES
# man SPECIES
# person SPECIES
# person SPECIES
# “many SPECIES
# ” he SPECIES
# children SPECIES
# woman SPECIES
# patients SPECIES
# “campaign SPECIES
# ” and SPECIES
# patients SPECIES
# children SPECIES
# people SPECIES
# human SPECIES
# patient SPECIES
# “smooth SPECIES
# ” coronavirus SPECIES
# patients SPECIES
# person SPECIES
# people SPECIES
# — Star SPECIES
# — on SPECIES
# patients SPECIES
# person SPECIES
# man SPECIES
# people SPECIES
# people SPECIES
# man SPECIES
# people SPECIES
# people SPECIES
# ...

# %% [markdown]
# #### ---> BC5CDR-chem <---

# %%
# !python -m spacy train config.cfg --output ./SPACYdata/Model/BC5CDR-chem/ --paths.train ./SPACYdata/train/iob_train_BC5CDR-chem.spacy --paths.dev ./SPACYdata/test/iob_test_BC5CDR-chem.spacy --gpu-id 0
# Out:
# 2021-04-25 19:20:48.624018: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# [2021-04-25 19:20:50,877] [INFO] Set up nlp object from config
# [2021-04-25 19:20:50,886] [INFO] Pipeline: ['transformer', 'ner']
# [2021-04-25 19:20:50,891] [INFO] Created vocabulary
# [2021-04-25 19:20:50,891] [INFO] Finished initializing nlp object
# [2021-04-25 19:20:59,360] [INFO] Initialized pipeline components: ['transformer', 'ner']
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['transformer', 'ner']
# ℹ Initial learn rate: 0.0
# E    #       LOSS TRANS...  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  -------------  --------  ------  ------  ------  ------
#   0       0       22199.52    890.51    0.26    0.25    0.26    0.00
# ...

# %%
nlp = spacy.load('SPACYdata/Model/BC5CDR-chem/model-best')
doc = nlp(text_join)
for ent in doc.ents:
  # Print the entity text and its label
  print(ent.text, ent.label_)
# Out:
# “every CHEMICALS
# ” The CHEMICALS
# “every CHEMICALS
# ” American CHEMICALS
# “nowhere CHEMICALS
# ” proper CHEMICALS
# ibuprofen CHEMICALS
# British American Tobacco CHEMICALS
# Fiat Chrysler Automobiles CHEMICALS
# FCA CHEMICALS
# — or CHEMICALS
# — puts CHEMICALS
# ibuprofen CHEMICALS
# “many CHEMICALS
# ” he CHEMICALS
# Novavax CHEMICALS
# “campaign CHEMICALS
# ” and CHEMICALS
# nitrogen dioxide CHEMICALS
# “smooth” coronavirus CHEMICALS
# Synairgen CHEMICALS
# — Star CHEMICALS
# — on CHEMICALS
# COVID-19, CHEMICALS
# … Harvard CHEMICALS
# COVID-19. CHEMICALS
# — or CHEMICALS
# — play CHEMICALS
# ’ anger CHEMICALS
# “There CHEMICALS
# ” The CHEMICALS
# “If CHEMICALS
# ” A CHEMICALS
# honey CHEMICALS
# alcohol CHEMICALS
# “mapped CHEMICALS
# ” proteins CHEMICALS
# — particularly CHEMICALS
# — one CHEMICALS
# — particularly CHEMICALS
# — one CHEMICALS
# Prezista CHEMICALS
# ’ sense CHEMICALS
# Durant CHEMICALS
# — and CHEMICALS
# Amazon CHEMICALS
# ’ far CHEMICALS
# ...

# %% [markdown]
# #### ---> BC5CDR-disease <---

# %%
# !python -m spacy train config.cfg --output ./SPACYdata/Model/BC5CDR-disease/ --paths.train ./SPACYdata/train/iob_train_BC5CDR-disease.spacy --paths.dev ./SPACYdata/test/iob_test_BC5CDR-disease.spacy --gpu-id 0
# Out:
# 2021-04-25 21:09:26.109342: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# [2021-04-25 21:09:28,392] [INFO] Set up nlp object from config
# [2021-04-25 21:09:28,401] [INFO] Pipeline: ['transformer', 'ner']
# [2021-04-25 21:09:28,405] [INFO] Created vocabulary
# [2021-04-25 21:09:28,406] [INFO] Finished initializing nlp object
# [2021-04-25 21:09:37,000] [INFO] Initialized pipeline components: ['transformer', 'ner']
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['transformer', 'ner']
# ℹ Initial learn rate: 0.0
# E    #       LOSS TRANS...  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  -------------  --------  ------  ------  ------  ------
#   0       0       22404.28    888.68    0.40    0.36    0.45    0.00
# ...

# %%
nlp = spacy.load('SPACYdata/Model/BC5CDR-disease/model-best')
doc = nlp(text_join)
for ent in doc.ents:
  # Print the entity text and its label
  print(ent.text, ent.label_)
# Out:
# infection DISEASE
# deaths DISEASE
# “every dollar donated is a dollar DISEASE
# ” The World Health Organization’s chief launched a global fund on Friday to raise money to help the world’s nations respond to the COVID-19 pandemic DISEASE
# “every dollar donated is a dollar towards saving lives DISEASE
# ” American Airlines Group Inc DISEASE
# breathlessness DISEASE
# wheezing DISEASE
# lung problems DISEASE
# infection DISEASE
# COVID-19 disease DISEASE
# pandemic DISEASE
# pandemic DISEASE
# theft DISEASE
# “nowhere near” proper readiness for outbreaks like the new coronavirus, insisting work is needed now to prepare for the next one DISEASE
# respiratory disease DISEASE
# infection DISEASE
# infection DISEASE
# HIV DISEASE
# infections DISEASE
# — or the "kung-flu DISEASE
# — puts Asian Americans at risk of retaliation despite growing reports they are facing virus-related discrimination DISEASE
# emphysema DISEASE
# respiratory illness DISEASE
# dry cough DISEASE
# fever DISEASE
# ...

# %% [markdown]
# #### ---> NCBI-disease <---

# %%
# !python -m spacy train config.cfg --output ./SPACYdata/Model/BC5CDR-disease/ --paths.train ./SPACYdata/train/iob_train_BC5CDR-disease.spacy --paths.dev ./SPACYdata/test/iob_test_NCBI-disease.spacy --gpu-id 0
# Out:
# 2021-04-25 22:32:34.086053: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# [2021-04-25 22:32:36,536] [INFO] Set up nlp object from config
# [2021-04-25 22:32:36,545] [INFO] Pipeline: ['transformer', 'ner']
# [2021-04-25 22:32:36,550] [INFO] Created vocabulary
# [2021-04-25 22:32:36,550] [INFO] Finished initializing nlp object
# [2021-04-25 22:32:44,416] [INFO] Initialized pipeline components: ['transformer', 'ner']
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['transformer', 'ner']
# ℹ Initial learn rate: 0.0
# E    #       LOSS TRANS...  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  -------------  --------  ------  ------  ------  ------
#   0       0       22404.28    888.68    1.10    0.98    1.25    0.01
# ...

# %%
nlp = spacy.load('SPACYdata/Model/BC5CDR-disease/model-best')
doc = nlp(text_join)
for ent in doc.ents:
  # Print the entity text and its label
  print(ent.text, ent.label_)
# Out:
# coronavirus DISEASE
# . A DISEASE
# .   DISEASE
# disease DISEASE
# coronavirus DISEASE
# . Members DISEASE
# . Social DISEASE
# coronavirus DISEASE
# infection DISEASE
# disease DISEASE
# . The DISEASE
# coronavirus DISEASE
# . Why DISEASE
# coronavirus DISEASE
# . U.S. DISEASE
# coronavirus DISEASE
# pandemic DISEASE
# “every dollar donated DISEASE
# .” DISEASE
# pandemic DISEASE
# “every dollar donated DISEASE
# .” DISEASE
# illnesses DISEASE
# breathlessness DISEASE
# wheezing DISEASE
# infection DISEASE
# coronavirus DISEASE
# .   DISEASE
# coronavirus DISEASE
# .   DISEASE
# coronavirus DISEASE
# pandemic DISEASE
# . But DISEASE
# . South DISEASE
# . IndyCar DISEASE
# pandemic DISEASE
# .   DISEASE
# pandemic DISEASE
# .   DISEASE
# coronavirus DISEASE
# pandemic DISEASE
# . A DISEASE
# coronavirus DISEASE
# .   DISEASE
# illness DISEASE
# coronavirus DISEASE
# . A DISEASE
# “nowhere DISEASE
# ” proper DISEASE
# coronavirus DISEASE
# . For DISEASE
# . A DISEASE
# ...

# %% [markdown]
# #### ---> BC2GM <---

# %%
# !python -m spacy train config.cfg --output ./SPACYdata/Model/BC2GM/ --paths.train ./SPACYdata/train/iob_train_BC2GM.spacy --paths.dev ./SPACYdata/test/iob_test_BC2GM.spacy --gpu-id 0
# Out:
# 2021-04-25 23:08:00.383351: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# [2021-04-25 23:08:02,668] [INFO] Set up nlp object from config
# [2021-04-25 23:08:02,677] [INFO] Pipeline: ['transformer', 'ner']
# [2021-04-25 23:08:02,682] [INFO] Created vocabulary
# [2021-04-25 23:08:02,682] [INFO] Finished initializing nlp object
# [2021-04-25 23:08:13,611] [INFO] Initialized pipeline components: ['transformer', 'ner']
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['transformer', 'ner']
# ℹ Initial learn rate: 0.0
# E    #       LOSS TRANS...  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  -------------  --------  ------  ------  ------  ------
#   0       0       15363.36    924.79    0.62    0.57    0.67    0.01
# ...

# %%
nlp = spacy.load('SPACYdata/Model/BC2GM/model-best')
doc = nlp(text_join)
for ent in doc.ents:
  # Print the entity text and its label
  print(ent.text, ent.label_)
# Out:
# “every dollar DRUG_PROTEIN
# ” The DRUG_PROTEIN
# “every dollar DRUG_PROTEIN
# ” American Airlines Group Inc DRUG_PROTEIN
# Covid-19 DRUG_PROTEIN
# “nowhere near DRUG_PROTEIN
# ” proper DRUG_PROTEIN
# — or DRUG_PROTEIN
# — puts DRUG_PROTEIN
# “many steps DRUG_PROTEIN
# ” he DRUG_PROTEIN
# “campaign DRUG_PROTEIN
# ” and DRUG_PROTEIN
# “smooth” DRUG_PROTEIN
# — Star DRUG_PROTEIN
# — on DRUG_PROTEIN
# COVID-19 DRUG_PROTEIN
# COVID-19 DRUG_PROTEIN
# … Harvard DRUG_PROTEIN
# — or DRUG_PROTEIN
# — play DRUG_PROTEIN
# ’ anger DRUG_PROTEIN
# “There DRUG_PROTEIN
# ” The DRUG_PROTEIN
# “If DRUG_PROTEIN
# ” A DRUG_PROTEIN
# “mapped DRUG_PROTEIN
# ” proteins DRUG_PROTEIN
# — particularly DRUG_PROTEIN
# — one DRUG_PROTEIN
# — particularly those DRUG_PROTEIN
# — one DRUG_PROTEIN
# ’ sense DRUG_PROTEIN
# — and DRUG_PROTEIN
# ’ far-flung peacekeeping DRUG_PROTEIN
# — and DRUG_PROTEIN
# “15 Days DRUG_PROTEIN
# — meaning just about everyone DRUG_PROTEIN
# “most likely DRUG_PROTEIN
# ” be DRUG_PROTEIN
# ...

# %% [markdown]
# #### ---> JNLPBA <---

# %%
# !python -m spacy train config.cfg --output ./SPACYdata/Model/JNLPBA/ --paths.train ./SPACYdata/train/iob_train_JNLPBA.spacy --paths.dev ./SPACYdata/test/iob_test_JNLPBA.spacy --gpu-id 0
# Out:
# 2021-04-26 01:02:38.455568: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# [2021-04-26 01:02:40,805] [INFO] Set up nlp object from config
# [2021-04-26 01:02:40,814] [INFO] Pipeline: ['transformer', 'ner']
# [2021-04-26 01:02:40,821] [INFO] Created vocabulary
# [2021-04-26 01:02:40,821] [INFO] Finished initializing nlp object
# [2021-04-26 01:02:52,647] [INFO] Initialized pipeline components: ['transformer', 'ner']
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['transformer', 'ner']
# ℹ Initial learn rate: 0.0
# E    #       LOSS TRANS...  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  -------------  --------  ------  ------  ------  ------
#   0       0        6632.94    590.82    0.48    0.51    0.46    0.00
# ...

# %%
nlp = spacy.load('SPACYdata/Model/JNLPBA/model-best')
doc = nlp(text_join)
for ent in doc.ents:
  # Print the entity text and its label
  print(ent.text, ent.label_)
# Out:
# “every DRUG_PROTEIN
# ” The DRUG_PROTEIN
# “every DRUG_PROTEIN
# ” American DRUG_PROTEIN
# “nowhere DRUG_PROTEIN
# ” proper DRUG_PROTEIN
# — or DRUG_PROTEIN
# — puts DRUG_PROTEIN
# Verily DRUG_PROTEIN
# “many DRUG_PROTEIN
# ” he DRUG_PROTEIN
# “campaign DRUG_PROTEIN
# ” and DRUG_PROTEIN
# “smooth DRUG_PROTEIN
# ” coronavirus DRUG_PROTEIN
# — Star DRUG_PROTEIN
# — on DRUG_PROTEIN
# … Harvard DRUG_PROTEIN
# — or DRUG_PROTEIN
# — play DRUG_PROTEIN
# ’ anger DRUG_PROTEIN
# “There DRUG_PROTEIN
# ” The DRUG_PROTEIN
# “If DRUG_PROTEIN
# ” A DRUG_PROTEIN
# “mapped DRUG_PROTEIN
# ” proteins DRUG_PROTEIN
# — particularly DRUG_PROTEIN
# — one DRUG_PROTEIN
# — particularly DRUG_PROTEIN
# — one DRUG_PROTEIN
# ’ sense DRUG_PROTEIN
# — and DRUG_PROTEIN
# ’ far DRUG_PROTEIN
# — and DRUG_PROTEIN
# “15 Days DRUG_PROTEIN
# — meaning DRUG_PROTEIN
# “most DRUG_PROTEIN
# ” be DRUG_PROTEIN
# — for DRUG_PROTEIN
# “most DRUG_PROTEIN
# ” be DRUG_PROTEIN
# — which DRUG_PROTEIN
# — announced DRUG_PROTEIN
# ...

# %% [markdown]
# #### ---> BC4CHEMD <---

# %%
# !python -m spacy train config.cfg --output ./SPACYdata/Model/BC4CHEMD/ --paths.train ./SPACYdata/train/iob_train_BC4CHEMD.spacy --paths.dev ./SPACYdata/test/iob_test_BC4CHEMD.spacy --gpu-id 0
# Out:
# 2021-04-26 02:25:02.942789: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# [2021-04-26 02:25:05,170] [INFO] Set up nlp object from config
# [2021-04-26 02:25:05,179] [INFO] Pipeline: ['transformer', 'ner']
# [2021-04-26 02:25:05,183] [INFO] Created vocabulary
# [2021-04-26 02:25:05,183] [INFO] Finished initializing nlp object
# [2021-04-26 02:25:31,463] [INFO] Initialized pipeline components: ['transformer', 'ner']
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['transformer', 'ner']
# ℹ Initial learn rate: 0.0
# E    #       LOSS TRANS...  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  -------------  --------  ------  ------  ------  ------
#   0       0       12986.20    591.69    0.30    0.25    0.36    0.00
# ...

# %%
nlp = spacy.load('SPACYdata/Model/BC4CHEMD/model-best')
doc = nlp(text_join)
for ent in doc.ents:
  # Print the entity text and its label
  print(ent.text, ent.label_)
# Out:
# “every dollar donated is a dollar towards saving lives. CHEMICALS
# ” The CHEMICALS
# “every CHEMICALS
# ” American Airlines Group Inc said on Thursday a pilot based out of Dallas CHEMICALS
# “nowhere CHEMICALS
# ” proper CHEMICALS
# ibuprofen CHEMICALS
# British American Tobacco CHEMICALS
# — or CHEMICALS
# — puts CHEMICALS
# ibuprofen CHEMICALS
# “many CHEMICALS
# ” he CHEMICALS
# “campaign CHEMICALS
# ” and CHEMICALS
# nitrogen dioxide CHEMICALS
# “smooth CHEMICALS
# ” coronavirus CHEMICALS
# — Star CHEMICALS
# — on CHEMICALS
# … Harvard CHEMICALS
# — or should — play CHEMICALS
# ’ anger CHEMICALS
# “There CHEMICALS
# ” The CHEMICALS
# “If CHEMICALS
# ” A CHEMICALS
# alcohol CHEMICALS
# “mapped CHEMICALS
# ” proteins CHEMICALS
# — particularly CHEMICALS
# — one CHEMICALS
# — particularly CHEMICALS
# — one CHEMICALS
# Prezista CHEMICALS
# ’ sense CHEMICALS
# — and CHEMICALS
# CPAC CHEMICALS
# ’ far CHEMICALS
# Cohen CHEMICALS
# Pfizer CHEMICALS
# Pfizer CHEMICALS
# — and CHEMICALS
# ...
